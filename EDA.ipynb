# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import yfinance as yf
import pandas as pd

# %%
#Descargamos el indice a analizar
sp500 = yf.download('^GSPC',start='1990-01-01')
sp500.reset_index(inplace=True)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
#Resumen de estadísticas descriptivas
sp500.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  8354.000000  8354.000000  8354.000000  8354.000000  8354.000000
# mean   1514.189182  1523.255963  1504.445139  1514.470564  1514.470564
# std    1009.988513  1015.632232  1003.814243  1010.045023  1010.045023
# min     295.450012   301.450012   294.510010   295.459991   295.459991
# 25%     882.575027   894.329987   873.669998   882.729996   882.729996
# 50%    1254.904968  1263.219971  1244.674988  1255.184998  1255.184998
# 75%    1965.607513  1977.612488  1957.614990  1967.817505  1967.817505
# max    4804.509766  4818.620117  4780.040039  4796.560059  4796.560059
#
#              Volume
# count  8.354000e+03
# mean   2.420314e+09
# std    1.851544e+09
# min    1.499000e+07
# 25%    6.113825e+08
# 50%    2.338280e+09
# 75%    3.805108e+09
# max    1.145623e+10

# %%
sp500.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
# Heatmap de correlaciones entre variables numéricas
sns.heatmap(sp500.corr(), cmap='coolwarm', annot=True)
plt.show()
#De esta manera podemos ver en que grado se afectan las distintas variables
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_10844\1157291213.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(sp500.corr(), cmap='coolwarm', annot=True)

# %%
# Histogramas de los precios de cierre
plt.hist(sp500['Close'],edgecolor = 'black')
plt.show()

# %%
#grafico de linea del precio de cierre respecto al tiempo
sp500['Date'] = pd.to_datetime(sp500['Date'])
sp500.set_index('Date', inplace=True)
sp500['Close'].plot(figsize=(12, 6))
plt.show()
#Es un grafico ideal para ver la tendencia que tiene el indicie y como fue evolucionando en el tiempo
#asi como ver sus coatizaciones mas bajas, donde podemos ver que las mismas coinciden con las
#crisis economicas

# %%
#Diagrama de caja de los precios de cierre
plt.boxplot(sp500['Close'],vert=False)

#Vemos aca que el diagrama de caja toma los valores mas altos como outlaiers, 
#esto se debe a que la cotizacion del sp500 a crecido exponencialmente respecto a como se venia 
#manejadndo el precio antiguamente.
#viendo el histograma, el diagrama de caja y el grafico de lineas podemos ver como la economia a 
#cambiado exponencialmente en las ultimas decadas
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x20bb3decc90>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x20bb3dedf50>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x20bb3da7e50>],
#  'medians': [<matplotlib.lines.Line2D at 0x20bb3deef50>],
#  'fliers': [<matplotlib.lines.Line2D at 0x20bad2a5ad0>],
#  'means': []}

# %%
#Gráfico de dispersión de la variable Volume respecto al tiempo
sns.set(style="darkgrid")
sns.scatterplot(x="Date", y="Volume", data=sp500)

# Mostrar el gráfico
plt.show()
